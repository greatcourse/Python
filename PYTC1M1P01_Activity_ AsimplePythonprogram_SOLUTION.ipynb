# %% [markdown]
# ## How to Interact with this Jupyter Notebook
# This notebook contains executable code combined with instructions to guide you through the activity.
#
# ### Scenario: The Rectangle Riddle
# You've just started your internship at Code Wizards Inc., a leading software development firm.
# On your first day, you're given a Python script that calculates the area of a rectangle.
# It's not working correctly, though. Your supervisor mentions there's a small error and challenges you to find and fix it.
#
# ### Instructions:
# - Carefully read the provided code snippet and then run it.
# - The code defines the length and width of a rectangle, calculates the area, and then attempts to print the result.
# - Pay close attention to the output - is the calculated area correct?
#
# ### Hints
# - **Identify and Fix the Error:** If the output isn't what you expected, use your knowledge of how to calculate the area of a rectangle (area = length * width) to spot the error in the code. Modify one line of code to correct the calculation.
# - **Run the Program Again:** Execute the modified script and verify that it now calculates and prints the area of the rectangle correctly. The output should clearly state the calculated area.

# %%
# The Code

length = 5
width = 3

# Calculate the area
area = length + width # Modify this line of code

# Print the result
print("The area of the rectangle is:", area)
# Out:
# The area of the rectangle is: 8

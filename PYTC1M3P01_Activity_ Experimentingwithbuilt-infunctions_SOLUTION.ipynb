# %% [markdown]
# ## How to Interact with this Jupyter Notebook
# This notebook contains executable code combined with instructions to guide you through the analysis of Antarctic temperatures.
#
# ### Exercise 1: Analyzing Antarctic Temperatures
# You'll analyze a series of daily temperature recordings from Antarctica to understand more about the extreme conditions in this remote region.
#
# ### Instructions:
# - Begin with the `antarctic_temperatures` list, which contains daily temperature recordings.
# - Use the `max()` and `min()` functions to find the highest and lowest temperatures recorded.
# - Calculate the average temperature using the `sum()` and `len()` functions and then round it to one decimal place.
# - Calculate the absolute value of the coldest temperature using the `abs()` function.
# - Print the highest, lowest, average, and absolute coldest temperatures.

# %%
# Provided temperature data
antarctic_temperatures = [-25.5, -28.0, -26.3, -23.8, -27.1, -24.9, -29.2]

# Find the highest and lowest temperatures
highest_temp = max(antarctic_temperatures)
lowest_temp = min(antarctic_temperatures)

print("Highest temperature:", highest_temp, "°C")
print("Lowest temperature:", lowest_temp, "°C")

# Calculate the average temperature
average_temp = round(sum(antarctic_temperatures) / len(antarctic_temperatures), 1)
print("Average temperature:", average_temp, "°C")

# Find the absolute value of the coldest temperature
coldest_temp_abs = abs(lowest_temp)
print("The coldest temperature was", coldest_temp_abs, "°C below freezing.")
# Out:
# Highest temperature: -23.8 °C
# Lowest temperature: -29.2 °C
# Average temperature: -26.4 °C
# The coldest temperature was 29.2 °C below freezing.
